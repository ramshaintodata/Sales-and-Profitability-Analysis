# %% [markdown]
# # Statistical Summary:
#
# The Sales data is highly skewed, with a few transactions reaching up to $11,199. Profit shows wide variation, ranging from a loss of $3,839 to a gain of $3,919, with a low average. Most orders include 2–5 items, though some reach up to 14. Discounts are typically 0% or 20%, but extreme discounts up to 80% impact profit. Postal Code and Row ID serve as identifiers and hold little analytical value.
# The Superstore dataset includes three main product categories and 17 sub-categories, with Office Supplies, Binders, and Paper being the most common. Customers fall into three segments, with Consumers making up over 50% of sales. The West region leads in orders, with data from 310 cities across 46 states. California and New York City are top contributors. Standard Class is the dominant shipping method, used in over 50% of orders. Most IDs are unique, indicating a broad customer and product base.

# %% [markdown]
# ** Non-Graphical Analysis:**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0a537bb3-6a5d-4e1b-95a8-3abf8952268a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0a537bb3-6a5d-4e1b-95a8-3abf8952268a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('Superstore Dataset.csv', encoding='ISO-8859-1')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1238 entries, 0 to 1237
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         1237 non-null   float64
#  1   Order ID       1237 non-null   object
#  2   Order Date     1237 non-null   object
#  3   Ship Date      1237 non-null   object
#  4   Ship Mode      1237 non-null   object
#  5   Customer ID    1237 non-null   object
#  6   Customer Name  1237 non-null   object
#  7   Segment        1237 non-null   object
#  8   Country        1237 non-null   object
#  9   City           1237 non-null   object
#  10  State          1237 non-null   object
#  11  Postal Code    1237 non-null   float64
#  12  Region         1237 non-null   object
#  13  Product ID     1237 non-null   object
#  14  Category       1237 non-null   object
#  15  Sub-Category   1237 non-null   object
#  16  Product Name   1237 non-null   object
# ...

# %%
categorical_cols = df.select_dtypes(include='object').columns
print("Categorical Columns:\n", list(categorical_cols))
# Out:
# Categorical Columns:
#  ['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name']

# %%
for col in categorical_cols:
    print(f"\n--- {col} ---")

    print("Top Value Counts:")
    print(df[col].value_counts().head(10))  # Top 10 most frequent values

    print("\nUnique Values:")
    print(df[col].unique())

    print("Number of Unique Values:", df[col].nunique())
# Out:
# --- Order ID ---
# Top Value Counts:
# Order ID
# CA-2015-164007    1
# CA-2016-152156    1
# CA-2016-121755    1
# CA-2015-149587    1
# US-2015-145436    1
# CA-2014-142951    1
# CA-2017-121048    1
# CA-2016-113656    1
# US-2016-150357    1
# CA-2014-137911    1
# Name: count, dtype: int64
#
# Unique Values:
# ['CA-2016-152156' 'CA-2016-121755' 'CA-2015-149587' ... 'CA-2016-150483'
#  'CA-2014-102645' 'CA-2015-164007']
# Number of Unique Values: 1237
#
# --- Order Date ---
# Top Value Counts:
# Order Date
# 6/8/2015      1
# 11/8/2016     1
# 1/16/2016     1
# 1/31/2015     1
# 2/28/2015     1
# 10/8/2014     1
# 7/14/2017     1
# 1/23/2016     1
# 10/10/2016    1
# 10/9/2014     1
# Name: count, dtype: int64
#
# Unique Values:
# ['11/8/2016' '1/16/2016' '1/31/2015' ... '5/31/2016' '1/23/2014'
#  '6/8/2015']
# Number of Unique Values: 1237
#
# --- Ship Date ---
# Top Value Counts:
# Ship Date
# 9/26/2017    4
# 8/23/2017    4
# 5/15/2014    4
# 11/9/2015    4
# 4/15/2017    4
# ...

# %% [markdown]
# **Graphical Analysis:**
#
#
# **Univariate Analysis  Numerical Features: **

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Superstore Dataset.csv', encoding='ISO-8859-1')

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
sns.set(style='whitegrid')

# %%
for col in numerical_cols:
    plt.figure(figsize=(15, 4))

# %% [markdown]
# **Distribution Plot**

# %%
plt.subplot(1, 3, 1)
sns.histplot(df[col], kde=True, color='orange')
plt.title(f'Distribution Plot of {col}')
# Out:
# Text(0.5, 1.0, 'Distribution Plot of Profit')

# %% [markdown]
#  **Count Plot**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-335dead3-1f0e-42f5-8f3e-6e96c6f94407" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-335dead3-1f0e-42f5-8f3e-6e96c6f94407">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Superstore Dataset.csv', encoding='ISO-8859-1')

# %%
print("Unique values in Quantity:", df['Quantity'].nunique())
# Out:
# Unique values in Quantity: 14

# %%
plt.figure(figsize=(8, 4))
sns.countplot(x='Quantity', data=df, palette='Set2')
plt.title('Count Plot of Quantity')
plt.show()
# Out:
# <ipython-input-14-eb6243eac57a>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Quantity', data=df, palette='Set2')

# %% [markdown]
# **Box Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='Profit', data=df, color='lightblue')
plt.title('Box Plot of Profit')
plt.xlabel('Profit')
plt.show()

# %% [markdown]
# **Univariate Analysis  Categorical Features: **

# %% [markdown]
# **Count Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
selected_cols = ['Ship Mode', 'City', 'Category']

# %%
top_cities = df['City'].value_counts().nlargest(10).index
plt.figure(figsize=(12, 4))
sns.countplot(x='City', data=df[df['City'].isin(top_cities)], order=top_cities, palette='Set2')
plt.title('Top 10 Cities by Order Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-76a8ca58d5df>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='City', data=df[df['City'].isin(top_cities)], order=top_cities, palette='Set2')

# %%
selected_cols = ['Ship Mode', 'Category']

# %%
for col in selected_cols:
    plt.figure(figsize=(8, 4))
    sns.countplot(x=col, data=df, palette='Set2', order=df[col].value_counts().index)
    plt.title(f'Count Plot of {col}', fontsize=14)
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=20)
    plt.tight_layout()
    plt.show()
# Out:
# <ipython-input-25-595bb977c200>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2', order=df[col].value_counts().index)
# <ipython-input-25-595bb977c200>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=col, data=df, palette='Set2', order=df[col].value_counts().index)

# %% [markdown]
# **Bivariate Analysis:**

# %% [markdown]
# ** Sales/Profit**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
df = pd.read_csv("Superstore Dataset.csv", encoding='ISO-8859-1')

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=category_sales.index, y=category_sales.values, palette="Blues_d")
plt.title("Total Sales by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-27-7dfcb5449b58>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_sales.index, y=category_sales.values, palette="Blues_d")

# %%
subcategory_sales = df.groupby("Sub-Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=subcategory_sales.index, y=subcategory_sales.values, palette="Greens_d")
plt.title("Total Sales by Sub-Category", fontsize=14)
plt.xlabel("Sub-Category", fontsize=12)
plt.ylabel("Total Sales", fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-28-4156b6f12e43>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=subcategory_sales.index, y=subcategory_sales.values, palette="Greens_d")

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Discount", y="Profit", alpha=0.6)
plt.title("Profit vs Discount")
plt.xlabel("Discount")
plt.ylabel("Profit")
plt.axhline(0, color='red', linestyle='--')  # Zero profit line
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x="Sales", y="Profit", alpha=0.6)
plt.title("Profit vs Sales")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.axhline(0, color='red', linestyle='--')  # Zero profit line
plt.tight_layout()
plt.show()

# %%
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
sns.barplot(x=category_profit.index, y=category_profit.values, palette="viridis")
plt.title("Total Profit by Category", fontsize=14)
plt.xlabel("Category", fontsize=12)
plt.ylabel("Total Profit", fontsize=12)
plt.xticks(rotation=45)
plt.axhline(0, color='red', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-31-0037eb1169bb>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=category_profit.index, y=category_profit.values, palette="viridis")

# %%
subcategory_profit = df.groupby("Sub-Category")["Profit"].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=subcategory_profit.index, y=subcategory_profit.values, palette="plasma")
plt.title("Total Profit by Sub-Category", fontsize=14)
plt.xlabel("Sub-Category", fontsize=12)
plt.ylabel("Total Profit", fontsize=12)
plt.xticks(rotation=45)
plt.axhline(0, color='red', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-32-b8cc6f67e2c1>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=subcategory_profit.index, y=subcategory_profit.values, palette="plasma")

# %% [markdown]
# The red line at y=0 highlights which segments are losing money for example sub-categories like Tables or Bookcases often show losses

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.dates as mdates

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3c82427-fc69-4114-94fd-e4439a59675c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3c82427-fc69-4114-94fd-e4439a59675c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Superstore Dataset.csv", encoding='ISO-8859-1')

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Month-Year"] = df["Order Date"].dt.to_period("M")
df["Profit Margin"] = df["Profit"] / df["Sales"].replace(0, 1e-5)

sns.set(style="whitegrid")

# %%
plt.figure(figsize=(14, 6))
pivot_margin = df.pivot_table(values='Profit Margin', index='Sub-Category', columns='Region', aggfunc='mean')
sns.heatmap(pivot_margin, annot=True, fmt=".2f", cmap="RdYlGn", linewidths=0.5)
plt.title("Profit Margin by Sub-Category and Region")
plt.xlabel("Region")
plt.ylabel("Sub-Category")
plt.tight_layout()
plt.show()

# %%
time_profit = df.groupby(["Month-Year", "Category"])["Profit"].sum().reset_index()
time_profit["Month-Year"] = time_profit["Month-Year"].astype(str)

plt.figure(figsize=(14, 6))
sns.lineplot(data=time_profit, x="Month-Year", y="Profit", hue="Category", marker="o")
plt.title("Monthly Profit Trends by Category")
plt.xticks(rotation=45)
plt.ylabel("Profit")
plt.xlabel("Month-Year")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df, x="Region", y="Profit", hue="Ship Mode", estimator=sum, ci=None)
plt.title("Total Profit by Region and Ship Mode")
plt.ylabel("Total Profit")
plt.xlabel("Region")
plt.legend(title="Ship Mode")
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-8-9a316b46e6cc>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="Region", y="Profit", hue="Ship Mode", estimator=sum, ci=None)

# %%
pairplot_data = df[["Sales", "Profit", "Discount", "Quantity", "Segment"]].dropna()
pairplot_data = pairplot_data[(pairplot_data[['Sales', 'Profit', 'Discount', 'Quantity']] >= 0).all(axis=1)]

sns.pairplot(pairplot_data, hue="Segment", diag_kind="kde", plot_kws={'alpha': 0.5})
plt.suptitle("Pairplot of Sales, Profit, Discount, and Quantity by Segment", y=1.02)
plt.show()

# %% [markdown]
# ** Correlation Analysis:**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Superstore Dataset.csv", encoding='ISO-8859-1')

# %%
df["Profit Margin"] = df["Profit"] / df["Sales"].replace(0, 1e-5)

# %%
numeric_cols = df[["Sales", "Profit", "Quantity", "Discount", "Profit Margin"]]
correlation_matrix = numeric_cols.corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Matrix of Numerical Features")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Outlier Detection:**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Superstore Dataset.csv", encoding='ISO-8859-1')
df["Profit Margin"] = df["Profit"] / df["Sales"].replace(0, 1e-5)

# %%
numeric_features = ["Sales", "Profit", "Discount", "Quantity", "Profit Margin"]

# %%
plt.figure(figsize=(15, 8))
for i, col in enumerate(numeric_features):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(data=df, y=col, color='skyblue')
    plt.title(f'Boxplot of {col}')
    plt.tight_layout()
plt.show()

# %%
outlier_summary = {}
for col in numeric_features:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower) | (df[col] > upper)]
    outlier_summary[col] = len(outliers)

# %%
print("Outlier Count by Feature:")
print(outlier_summary)
# Out:
# Outlier Count by Feature:
# {'Sales': 144, 'Profit': 256, 'Discount': 101, 'Quantity': 18, 'Profit Margin': 121}

# %% [markdown]
# **CONDITIONAL ANALYSIS FOR SUPERSTORE DATA**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Superstore Dataset.csv", encoding='ISO-8859-1')

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])
df["Profit Margin"] = df["Profit"] / df["Sales"].replace(0, 1e-5)
df["High Discount"] = df["Discount"] > 0.3
df["Loss"] = df["Profit"] < 0
df["Delivery Delay"] = (df["Ship Date"] - df["Order Date"]).dt.days

# %%
segment_region_pct = df.groupby(["Segment", "Region"]).size() / len(df) * 100

# %%
avg_sales_profit = df.groupby(["Segment", "Region"])[["Sales", "Profit"]].mean()

# %%
df["Discount Bin"] = pd.cut(df["Discount"], bins=[-0.01, 0.1, 0.2, 0.3, 0.5, 1.0])
discount_profit_cat = df.groupby(["Category", "Discount Bin"])["Profit"].mean().unstack()
# Out:
# <ipython-input-26-d924fc91fff2>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   discount_profit_cat = df.groupby(["Category", "Discount Bin"])["Profit"].mean().unstack()

# %%
high_discount_loss_pct = df[df["High Discount"]]["Loss"].mean() * 100

# %%
repeat_counts = df["Customer ID"].value_counts()
repeat_ids = repeat_counts[repeat_counts > 1].index
df["Repeat Buyer"] = df["Customer ID"].isin(repeat_ids)
repeat_spend = df.groupby("Repeat Buyer")[["Sales", "Profit"]].mean()
repeat_pct = df["Repeat Buyer"].mean() * 100

# %%
loss_by_subcat = df[df["Loss"]].groupby("Sub-Category")[["Profit", "Sales"]].sum()
loss_by_subcat["Loss %"] = -loss_by_subcat["Profit"] / loss_by_subcat["Sales"] * 100
loss_by_subcat = loss_by_subcat.sort_values("Loss %", ascending=False)

# %%
prob_profit = df.groupby("Discount Bin")["Profit"].apply(lambda x: (x > 0).mean())
# Out:
# <ipython-input-30-d5a42b2c1160>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   prob_profit = df.groupby("Discount Bin")["Profit"].apply(lambda x: (x > 0).mean())

# %%
unprofitable_orders = df[df["Profit"] < 0]
unprofitable_cat_region = unprofitable_orders.groupby(["Category", "Region"]).size().unstack().fillna(0)

# %%
avg_delay = df["Delivery Delay"].mean()
delay_by_seg_cat = df.groupby(["Segment", "Category"])["Delivery Delay"].mean()

# %%
region_perf = df.groupby(["Segment", "Region"])[["Sales", "Profit"]].mean().unstack()

# %%
subcat_stats = df.groupby("Sub-Category")[["Discount", "Profit"]].mean()
profitable_high_discount = subcat_stats[(subcat_stats["Discount"] > 0.3) & (subcat_stats["Profit"] > 0)]

# %%
print(f" Repeat Buyer %: {repeat_pct:.2f}%")
# Out:
#  Repeat Buyer %: 77.38%

# %%
print(f" Average Delivery Delay: {avg_delay:.2f} days")
# Out:
#  Average Delivery Delay: 3.95 days

# %%
print("\n % of Orders by Segment and Region:\n", segment_region_pct)
print("\n Avg Sales and Profit per Segment/Region:\n", avg_sales_profit)
print("\n Profitability across Discount Bins by Category:\n", discount_profit_cat)
print("\n Repeat Buyer Spend vs One-Time:\n", repeat_spend)
print("\n Sub-Categories with Highest % Loss:\n", loss_by_subcat[["Loss %"]])
print("\n P(Profit > 0) by Discount Bin:\n", prob_profit)
# Out:
#  % of Orders by Segment and Region:
#  Segment      Region
# Consumer     Central    12.358643
#              East       13.085622
#              South       9.369952
#              West       17.285945
# Corporate    Central     6.704362
#              East        8.239095
#              South       5.088853
#              West        9.854604
# Home Office  Central     4.927302
#              East        4.604200
#              South       3.150242
#              West        5.250404
# dtype: float64
#
#  Avg Sales and Profit per Segment/Region:
#                            Sales     Profit
# Segment     Region
# Consumer    Central  207.676732  -0.673203
#             East     164.668272  -0.179506
#             South    261.287586  17.162845
#             West     177.698832  18.618037
# Corporate   Central  349.311687  43.390843
#             East     173.983431  16.270490
#             South    319.435397 -19.194921
#             West     221.825410  39.620656
# ...

# %% [markdown]
# # After analyzing the Superstore data, a few key takeaways stand out. Discounts over 30% often lead to losses, especially in sub-categories like Tables and Bookcases, so it’s worth rethinking our pricing strategy. The Consumer segment performs well across all regions, making it a good target for focused marketing. Repeat buyers spend more and make up a large part of revenue, so loyalty programs or special offers could help increase retention. Some sub-categories, like Binders and Paper, stay profitable even with discounts, these are great options for bundling or upselling. Overall, we need smarter discounting and better customer targeting to grow both sales and profit.
